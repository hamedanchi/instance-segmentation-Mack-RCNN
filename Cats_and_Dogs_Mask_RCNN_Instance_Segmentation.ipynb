# %%
# !nvidia-smi
# Out:
# Sun Jun  4 18:26:48 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   58C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !python -m pip install roboflow
# !python -m pip install 'git+https://github.com/facebookresearch/detectron2.git'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting roboflow
#   Downloading roboflow-1.0.9-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: certifi==2022.12.7 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2022.12.7)
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.0.0)
# Collecting cycler==0.10.0 (from roboflow)
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting idna==2.10 (from roboflow)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.22.4)
# Requirement already satisfied: opencv-python>=4.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.7.0.72)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (8.4.0)
# Collecting pyparsing==2.4.7 (from roboflow)
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.27.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.26.15)
# Collecting wget (from roboflow)
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.65.0)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0)
# Collecting requests-toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.39.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (23.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (2.0.12)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9657 sha256=2333cf15b51f50b8981ed2826a309a96bdd1665a7ca5efd9d360e0ad19447b64
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# Installing collected packages: wget, python-dotenv, pyparsing, idna, cycler, requests-toolbelt, roboflow
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.11.0
#     Uninstalling cycler-0.11.0:
#       Successfully uninstalled cycler-0.11.0
# Successfully installed cycler-0.10.0 idna-2.10 pyparsing-2.4.7 python-dotenv-1.0.0 requests-toolbelt-1.0.0 roboflow-1.0.9 wget-3.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/facebookresearch/detectron2.git
#   Cloning https://github.com/facebookresearch/detectron2.git to /tmp/pip-req-build-72m9bsy8
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /tmp/pip-req-build-72m9bsy8
#   Resolved https://github.com/facebookresearch/detectron2.git to commit dd2db71b0f8d855b71cac655186cbddca1bfda93
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow>=7.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (8.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (3.7.1)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.0.6)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.3.0)
# Collecting yacs>=0.1.8 (from detectron2==0.6)
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (0.8.10)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.2.1)
# Requirement already satisfied: tqdm>4.29.0 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (4.65.0)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.12.2)
# Collecting fvcore<0.1.6,>=0.1.5 (from detectron2==0.6)
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting iopath<0.1.10,>=0.1.7 (from detectron2==0.6)
#   Downloading iopath-0.1.9-py3-none-any.whl (27 kB)
# Collecting omegaconf>=2.1 (from detectron2==0.6)
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 10.3 MB/s eta 0:00:00
# Collecting hydra-core>=1.1 (from detectron2==0.6)
#   Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 21.0 MB/s eta 0:00:00
# Collecting black (from detectron2==0.6)
#   Downloading black-23.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 88.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (23.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (1.22.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (6.0)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core>=1.1->detectron2==0.6)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 17.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting portalocker (from iopath<0.1.10,>=0.1.7->detectron2==0.6)
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (2.8.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (8.1.3)
# Collecting mypy-extensions>=0.4.3 (from black->detectron2==0.6)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting pathspec>=0.9.0 (from black->detectron2==0.6)
#   Downloading pathspec-0.11.1-py3-none-any.whl (29 kB)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (3.3.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (2.0.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.54.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.4.3)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (2.27.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (2.3.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (0.40.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from cycler>=0.10->matplotlib->detectron2==0.6) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2==0.6) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2.10)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard->detectron2==0.6) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2==0.6) (3.2.2)
# Building wheels for collected packages: detectron2, fvcore, antlr4-python3-runtime
#   Building wheel for detectron2 (setup.py) ... done
#   Created wheel for detectron2: filename=detectron2-0.6-cp310-cp310-linux_x86_64.whl size=7802838 sha256=efae4703a41fe86cc2831d4d70e1371dca5732a989cfbc5f79dad64cd247d637
#   Stored in directory: /tmp/pip-ephem-wheel-cache-h5g7p6d2/wheels/47/e5/15/94c80df2ba85500c5d76599cc307c0a7079d0e221bb6fc4375
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61405 sha256=fe157d5796f8f4256544a4706325e9a06425c8ec8da5e676aeaccb428d141dd7
#   Stored in directory: /root/.cache/pip/wheels/01/c0/af/77c1cf53a1be9e42a52b48e5af2169d40ec2e89f7362489dd0
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=8772742d9838d56c09a806da573727a12c66714f0dda778d1063da8e7161eb63
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built detectron2 fvcore antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime, yacs, portalocker, pathspec, omegaconf, mypy-extensions, iopath, hydra-core, black, fvcore, detectron2
# Successfully installed antlr4-python3-runtime-4.9.3 black-23.3.0 detectron2-0.6 fvcore-0.1.5.post20221221 hydra-core-1.3.2 iopath-0.1.9 mypy-extensions-1.0.0 omegaconf-2.3.0 pathspec-0.11.1 portalocker-2.7.0 yacs-0.1.8

# %%
import logging
import torch
from collections import OrderedDict
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

# import some common libraries
import numpy as np
import os, json, cv2, random

# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog
from detectron2.data.datasets import register_coco_instances
from detectron2.engine import DefaultTrainer
from detectron2.utils.visualizer import ColorMode
from detectron2.solver import build_lr_scheduler, build_optimizer
from detectron2.checkpoint import DetectionCheckpointer, PeriodicCheckpointer
from detectron2.utils.events import EventStorage
from detectron2.modeling import build_model
import detectron2.utils.comm as comm
from detectron2.engine import default_argument_parser, default_setup, default_writers, launch
from detectron2.data import (
    MetadataCatalog,
    build_detection_test_loader,
    build_detection_train_loader,
)
from detectron2.evaluation import (
    CityscapesInstanceEvaluator,
    CityscapesSemSegEvaluator,
    COCOEvaluator,
    COCOPanopticEvaluator,
    DatasetEvaluators,
    LVISEvaluator,
    PascalVOCDetectionEvaluator,
    SemSegEvaluator,
    inference_on_dataset,
    print_csv_format,
)



from matplotlib import pyplot as plt
from PIL import Image

# %%
# !pip install roboflow



from roboflow import Roboflow
rf = Roboflow(api_key="EWAylTcfsnrFBe2iK70c")
project = rf.workspace("project-d7sq5").project("data-cat")
dataset = project.version(2).download("coco")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: roboflow in /usr/local/lib/python3.10/dist-packages (1.0.9)
# Requirement already satisfied: certifi==2022.12.7 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2022.12.7)
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.0.0)
# Requirement already satisfied: cycler==0.10.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.10.0)
# Requirement already satisfied: idna==2.10 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.10)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.22.4)
# Requirement already satisfied: opencv-python>=4.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.7.0.72)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (8.4.0)
# Requirement already satisfied: pyparsing==2.4.7 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.4.7)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.27.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.26.15)
# Requirement already satisfied: wget in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.2)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.65.0)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.39.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (23.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (2.0.12)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in data-cat-2 to coco: 100% [18224945 / 18224945] bytes
# Extracting Dataset Version Zip to data-cat-2 in coco:: 100%|██████████| 286/286 [00:00<00:00, 1601.64it/s]

# %%
DatasetCatalog.clear()
MetadataCatalog.clear()

# %%
register_coco_instances("cats-train", {}, "./data-cat-2/train/_annotations.coco.json", "./data-cat-2/train/")
register_coco_instances("cats-valid", {}, "./data-cat-2/valid/_annotations.coco.json", "./data-cat-2/valid/")

# %%
from detectron2.data import MetadataCatalog, DatasetCatalog
from matplotlib import pyplot as plt
dataset_train = DatasetCatalog.get("cats-train")
fig, ax = plt.subplots()
dataset_dict = random.choice(dataset_train)
im = Image.open(dataset_dict['file_name'])
ax.imshow(im)
for ann in dataset_dict['annotations']:
    for poly in ann['segmentation']:
        x = poly[0::2]
        y = poly[1::2]
        ax.plot(x,y, linewidth=2, color='red')
# Out:
# WARNING [06/04 18:32:43 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [06/04 18:32:43 d2.data.datasets.coco]: Loaded 240 images in COCO format from ./data-cat-2/train/_annotations.coco.json

# %%
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
cfg.DATASETS.TRAIN = ("cats-train",)#Train dataset registered in a previous cell
cfg.DATASETS.TEST = ("cats-valid",)#Test dataset registered in a previous cell
cfg.DATALOADER.NUM_WORKERS = 2
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")  # Let training initialize from model zoo
cfg.SOLVER.IMS_PER_BATCH = 2
cfg.SOLVER.BASE_LR = 0.00025
cfg.SOLVER.MAX_ITER = 10000 #We found that with a patience of 500, training will early stop before 10,000 iterations
cfg.SOLVER.STEPS = []
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 512
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 27 # 26 letters plus one super class
cfg.TEST.EVAL_PERIOD = 0 # Increase this number if you want to monitor validation performance during training

PATIENCE = 500 #Early stopping will occur after N iterations of no imporovement in total_loss

#os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)

# %%
def get_evaluator(cfg, dataset_name, output_folder=None):
    """
    Create evaluator(s) for a given dataset.
    This uses the special metadata "evaluator_type" associated with each builtin dataset.
    For your own dataset, you can simply create an evaluator manually in your
    script and do not have to worry about the hacky if-else logic here.
    """
    if output_folder is None:
        output_folder = os.path.join(cfg.OUTPUT_DIR, "inference")
    evaluator_list = []
    evaluator_type = MetadataCatalog.get(dataset_name).evaluator_type
    if evaluator_type in ["sem_seg", "coco_panoptic_seg"]:
        evaluator_list.append(
            SemSegEvaluator(
                dataset_name,
                distributed=True,
                output_dir=output_folder,
            )
        )
    if evaluator_type in ["coco", "coco_panoptic_seg"]:
        evaluator_list.append(COCOEvaluator(dataset_name, output_dir=output_folder))
    if evaluator_type == "coco_panoptic_seg":
        evaluator_list.append(COCOPanopticEvaluator(dataset_name, output_folder))
    if evaluator_type == "cityscapes_instance":
        return CityscapesInstanceEvaluator(dataset_name)
    if evaluator_type == "cityscapes_sem_seg":
        return CityscapesSemSegEvaluator(dataset_name)
    if evaluator_type == "pascal_voc":
        return PascalVOCDetectionEvaluator(dataset_name)
    if evaluator_type == "lvis":
        return LVISEvaluator(dataset_name, cfg, True, output_folder)
    if len(evaluator_list) == 0:
        raise NotImplementedError(
            "no Evaluator for the dataset {} with the type {}".format(dataset_name, evaluator_type)
        )
    if len(evaluator_list) == 1:
        return evaluator_list[0]
    return DatasetEvaluators(evaluator_list)

def do_test(cfg, model):
    results = OrderedDict()
    for dataset_name in cfg.DATASETS.TEST:
        data_loader = build_detection_test_loader(cfg, dataset_name)
        evaluator = get_evaluator(
            cfg, dataset_name, os.path.join(cfg.OUTPUT_DIR, "inference", dataset_name)
        )
        results_i = inference_on_dataset(model, data_loader, evaluator)
        results[dataset_name] = results_i
        if comm.is_main_process():
            logger.info("Evaluation results for {} in csv format:".format(dataset_name))
            print_csv_format(results_i)
    if len(results) == 1:
        results = list(results.values())[0]
    return results


logger = logging.getLogger("detectron2")
resume=False
model = build_model(cfg)
optimizer = build_optimizer(cfg, model)
scheduler = build_lr_scheduler(cfg, optimizer)

BEST_LOSS = np.inf

checkpointer = DetectionCheckpointer(
    model, cfg.OUTPUT_DIR, optimizer=optimizer, scheduler=scheduler
)
start_iter = (
    checkpointer.resume_or_load(cfg.MODEL.WEIGHTS, resume=resume).get("iteration", -1) + 1
)
prev_iter = start_iter
max_iter = cfg.SOLVER.MAX_ITER

periodic_checkpointer = PeriodicCheckpointer(
    checkpointer, cfg.SOLVER.CHECKPOINT_PERIOD, max_iter=max_iter
)

writers = default_writers(cfg.OUTPUT_DIR, max_iter) if comm.is_main_process() else []

# compared to "train_net.py", we do not support accurate timing and
# precise BN here, because they are not trivial to implement in a small training loop
data_loader = build_detection_train_loader(cfg)
logger.info("Starting training from iteration {}".format(start_iter))
patience_counter = 0
with EventStorage(start_iter) as storage:
    for data, iteration in zip(data_loader, range(start_iter, max_iter)):
        storage.iter = iteration

        loss_dict = model(data)
        losses = sum(loss_dict.values())
        assert torch.isfinite(losses).all(), loss_dict

        loss_dict_reduced = {k: v.item() for k, v in comm.reduce_dict(loss_dict).items()}
        losses_reduced = sum(loss for loss in loss_dict_reduced.values())
        if comm.is_main_process():
            storage.put_scalars(total_loss=losses_reduced, **loss_dict_reduced)

        optimizer.zero_grad()
        losses.backward()
        optimizer.step()
        storage.put_scalar("lr", optimizer.param_groups[0]["lr"], smoothing_hint=False)
        scheduler.step()

        if (
            cfg.TEST.EVAL_PERIOD > 0
            and (iteration + 1) % cfg.TEST.EVAL_PERIOD == 0
            and iteration != max_iter - 1
        ):
            do_test(cfg, model)
            # Compared to "train_net.py", the test results are not dumped to EventStorage
            comm.synchronize()

        if iteration - start_iter > 5 and (
            (iteration + 1) % 20 == 0 or iteration == max_iter - 1
        ):
            for writer in writers:
                writer.write()
        periodic_checkpointer.step(iteration)
        
        if iteration > prev_iter:
            prev_iter = iteration
            if losses_reduced < BEST_LOSS:
                BEST_LOSS = losses_reduced
                patience_counter = 0
            else:
                patience_counter += 1
                if patience_counter % 100 == 0:
                    print(f"Loss has not improved for {patience_counter} iterations")
                if patience_counter >= PATIENCE:
                    print(f"EARLY STOPPING")
                    break
                
do_test(cfg, model)
# Out:
# [06/04 20:02:30 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x/137849600/model_final_f10217.pkl ...
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (28, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (28,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (108, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (108,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.mask_head.predictor.weight' to the model due to incompatible shapes: (80, 256, 1, 1) in the checkpoint but (27, 256, 1, 1) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.mask_head.predictor.bias' to the model due to incompatible shapes: (80,) in the checkpoint but (27,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# roi_heads.mask_head.predictor.{bias, weight}
# WARNING [06/04 20:02:30 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [06/04 20:02:30 d2.data.datasets.coco]: Loaded 240 images in COCO format from ./data-cat-2/train/_annotations.coco.json
# [06/04 20:02:30 d2.data.build]: Removed 0 images with no usable annotations. 240 images left.
# [06/04 20:02:30 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [06/04 20:02:30 d2.data.build]: Using training sampler TrainingSampler
# [06/04 20:02:30 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [06/04 20:02:30 d2.data.common]: Serializing 240 elements to byte tensors and concatenating them all ...
# [06/04 20:02:30 d2.data.common]: Serialized dataset takes 0.67 MiB
# [06/04 20:02:30 detectron2]: Starting training from iteration 0
# [06/04 20:02:38 d2.utils.events]:  iter: 19  total_loss: 4.099  loss_cls: 3.204  loss_box_reg: 0.1314  loss_mask: 0.6935  loss_rpn_cls: 0.004822  loss_rpn_loc: 0.005633     lr: 4.9953e-06  max_mem: 6054M
# [06/04 20:02:45 d2.utils.events]:  eta: 1:02:28  iter: 39  total_loss: 3.87  loss_cls: 3.022  loss_box_reg: 0.1382  loss_mask: 0.6876  loss_rpn_cls: 0.002463  loss_rpn_loc: 0.006271     lr: 9.9902e-06  max_mem: 6054M
# [06/04 20:02:53 d2.utils.events]:  eta: 1:03:53  iter: 59  total_loss: 3.438  loss_cls: 2.56  loss_box_reg: 0.1638  loss_mask: 0.6704  loss_rpn_cls: 0.002676  loss_rpn_loc: 0.005798     lr: 1.4985e-05  max_mem: 6054M
# [06/04 20:03:01 d2.utils.events]:  eta: 1:04:27  iter: 79  total_loss: 2.753  loss_cls: 1.896  loss_box_reg: 0.1665  loss_mask: 0.6477  loss_rpn_cls: 0.003501  loss_rpn_loc: 0.005107     lr: 1.998e-05  max_mem: 6054M
# [06/04 20:03:08 d2.utils.events]:  eta: 0:59:49  iter: 99  total_loss: 1.871  loss_cls: 1.058  loss_box_reg: 0.1357  loss_mask: 0.6234  loss_rpn_cls: 0.00351  loss_rpn_loc: 0.005458     lr: 2.4975e-05  max_mem: 6054M
# [06/04 20:03:16 d2.utils.events]:  eta: 1:03:46  iter: 119  total_loss: 1.352  loss_cls: 0.5221  loss_box_reg: 0.2251  loss_mask: 0.5995  loss_rpn_cls: 0.002862  loss_rpn_loc: 0.005876     lr: 2.997e-05  max_mem: 6054M
# [06/04 20:03:23 d2.utils.events]:  eta: 1:01:50  iter: 139  total_loss: 1.08  loss_cls: 0.3144  loss_box_reg: 0.1626  loss_mask: 0.5502  loss_rpn_cls: 0.001439  loss_rpn_loc: 0.005258     lr: 3.4965e-05  max_mem: 6054M
# [06/04 20:03:31 d2.utils.events]:  eta: 1:01:56  iter: 159  total_loss: 0.9203  loss_cls: 0.2579  loss_box_reg: 0.1957  loss_mask: 0.5165  loss_rpn_cls: 0.00175  loss_rpn_loc: 0.006628     lr: 3.996e-05  max_mem: 6054M
# [06/04 20:03:38 d2.utils.events]:  eta: 1:00:19  iter: 179  total_loss: 0.8433  loss_cls: 0.2269  loss_box_reg: 0.1397  loss_mask: 0.4588  loss_rpn_cls: 0.0009519  loss_rpn_loc: 0.004853     lr: 4.4955e-05  max_mem: 6054M
# [06/04 20:03:46 d2.utils.events]:  eta: 1:02:47  iter: 199  total_loss: 0.8254  loss_cls: 0.1912  loss_box_reg: 0.1442  loss_mask: 0.4456  loss_rpn_cls: 0.0003099  loss_rpn_loc: 0.006207     lr: 4.995e-05  max_mem: 6054M
# [06/04 20:03:54 d2.utils.events]:  eta: 1:02:00  iter: 219  total_loss: 0.7855  loss_cls: 0.2103  loss_box_reg: 0.1775  loss_mask: 0.4001  loss_rpn_cls: 0.0009917  loss_rpn_loc: 0.005782     lr: 5.4945e-05  max_mem: 6054M
# [06/04 20:04:01 d2.utils.events]:  eta: 1:03:20  iter: 239  total_loss: 0.8385  loss_cls: 0.2578  loss_box_reg: 0.1869  loss_mask: 0.3478  loss_rpn_cls: 0.0009953  loss_rpn_loc: 0.005563     lr: 5.994e-05  max_mem: 6054M
# [06/04 20:04:09 d2.utils.events]:  eta: 1:00:30  iter: 259  total_loss: 0.6306  loss_cls: 0.165  loss_box_reg: 0.1519  loss_mask: 0.3196  loss_rpn_cls: 0.0007285  loss_rpn_loc: 0.005817     lr: 6.4935e-05  max_mem: 6054M
# [06/04 20:04:16 d2.utils.events]:  eta: 1:01:16  iter: 279  total_loss: 0.6728  loss_cls: 0.167  loss_box_reg: 0.1655  loss_mask: 0.2765  loss_rpn_cls: 0.0007817  loss_rpn_loc: 0.005697     lr: 6.993e-05  max_mem: 6054M
# [06/04 20:04:24 d2.utils.events]:  eta: 0:59:40  iter: 299  total_loss: 0.5124  loss_cls: 0.1362  loss_box_reg: 0.1602  loss_mask: 0.242  loss_rpn_cls: 0.0003452  loss_rpn_loc: 0.006343     lr: 7.4925e-05  max_mem: 6054M
# [06/04 20:04:31 d2.utils.events]:  eta: 1:00:40  iter: 319  total_loss: 0.6037  loss_cls: 0.1623  loss_box_reg: 0.1695  loss_mask: 0.2314  loss_rpn_cls: 0.001299  loss_rpn_loc: 0.006412     lr: 7.992e-05  max_mem: 6054M
# [06/04 20:04:39 d2.utils.events]:  eta: 1:02:46  iter: 339  total_loss: 0.5591  loss_cls: 0.1465  loss_box_reg: 0.1769  loss_mask: 0.2268  loss_rpn_cls: 0.0004611  loss_rpn_loc: 0.007435     lr: 8.4915e-05  max_mem: 6054M
# [06/04 20:04:47 d2.utils.events]:  eta: 1:01:05  iter: 359  total_loss: 0.5171  loss_cls: 0.1328  loss_box_reg: 0.2118  loss_mask: 0.19  loss_rpn_cls: 0.0006827  loss_rpn_loc: 0.006307     lr: 8.991e-05  max_mem: 6054M
# [06/04 20:04:54 d2.utils.events]:  eta: 1:01:51  iter: 379  total_loss: 0.5027  loss_cls: 0.1118  loss_box_reg: 0.1584  loss_mask: 0.1636  loss_rpn_cls: 0.0005437  loss_rpn_loc: 0.0055     lr: 9.4905e-05  max_mem: 6054M
# [06/04 20:05:02 d2.utils.events]:  eta: 1:02:37  iter: 399  total_loss: 0.4254  loss_cls: 0.102  loss_box_reg: 0.1642  loss_mask: 0.1482  loss_rpn_cls: 0.0002981  loss_rpn_loc: 0.005749     lr: 9.99e-05  max_mem: 6054M
# [06/04 20:05:11 d2.utils.events]:  eta: 1:07:39  iter: 419  total_loss: 0.4311  loss_cls: 0.0889  loss_box_reg: 0.1643  loss_mask: 0.1649  loss_rpn_cls: 0.0006006  loss_rpn_loc: 0.005671     lr: 0.0001049  max_mem: 6054M
# [06/04 20:05:18 d2.utils.events]:  eta: 1:00:06  iter: 439  total_loss: 0.4108  loss_cls: 0.08266  loss_box_reg: 0.187  loss_mask: 0.1307  loss_rpn_cls: 0.0003015  loss_rpn_loc: 0.004288     lr: 0.00010989  max_mem: 6054M
# [06/04 20:05:27 d2.utils.events]:  eta: 1:06:28  iter: 459  total_loss: 0.3999  loss_cls: 0.08769  loss_box_reg: 0.1869  loss_mask: 0.1643  loss_rpn_cls: 0.0004232  loss_rpn_loc: 0.006062     lr: 0.00011489  max_mem: 6054M
# [06/04 20:05:35 d2.utils.events]:  eta: 1:02:35  iter: 479  total_loss: 0.4359  loss_cls: 0.09065  loss_box_reg: 0.1815  loss_mask: 0.1563  loss_rpn_cls: 0.0004659  loss_rpn_loc: 0.007874     lr: 0.00011988  max_mem: 6054M
# [06/04 20:05:43 d2.utils.events]:  eta: 1:03:55  iter: 499  total_loss: 0.4544  loss_cls: 0.0838  loss_box_reg: 0.2127  loss_mask: 0.131  loss_rpn_cls: 0.0002629  loss_rpn_loc: 0.008247     lr: 0.00012488  max_mem: 6054M
# [06/04 20:05:50 d2.utils.events]:  eta: 0:59:54  iter: 519  total_loss: 0.3968  loss_cls: 0.07045  loss_box_reg: 0.159  loss_mask: 0.1392  loss_rpn_cls: 0.0002294  loss_rpn_loc: 0.007629     lr: 0.00012987  max_mem: 6054M
# [06/04 20:05:58 d2.utils.events]:  eta: 1:00:21  iter: 539  total_loss: 0.3049  loss_cls: 0.05014  loss_box_reg: 0.1093  loss_mask: 0.1147  loss_rpn_cls: 0.0002852  loss_rpn_loc: 0.004254     lr: 0.00013487  max_mem: 6054M
# Loss has not improved for 100 iterations
# [06/04 20:06:06 d2.utils.events]:  eta: 1:01:01  iter: 559  total_loss: 0.3422  loss_cls: 0.0643  loss_box_reg: 0.1338  loss_mask: 0.1215  loss_rpn_cls: 0.0003757  loss_rpn_loc: 0.006634     lr: 0.00013986  max_mem: 6054M
# [06/04 20:06:13 d2.utils.events]:  eta: 1:01:50  iter: 579  total_loss: 0.3661  loss_cls: 0.0661  loss_box_reg: 0.1392  loss_mask: 0.1174  loss_rpn_cls: 0.0001318  loss_rpn_loc: 0.007609     lr: 0.00014486  max_mem: 6054M
# [06/04 20:06:21 d2.utils.events]:  eta: 1:01:25  iter: 599  total_loss: 0.2684  loss_cls: 0.0599  loss_box_reg: 0.09763  loss_mask: 0.1305  loss_rpn_cls: 0.0003853  loss_rpn_loc: 0.009307     lr: 0.00014985  max_mem: 6054M
# [06/04 20:06:29 d2.utils.events]:  eta: 0:59:34  iter: 619  total_loss: 0.2822  loss_cls: 0.05134  loss_box_reg: 0.0737  loss_mask: 0.1143  loss_rpn_cls: 0.0005277  loss_rpn_loc: 0.00867     lr: 0.00015485  max_mem: 6054M
# [06/04 20:06:37 d2.utils.events]:  eta: 0:59:26  iter: 639  total_loss: 0.3179  loss_cls: 0.05236  loss_box_reg: 0.09399  loss_mask: 0.1333  loss_rpn_cls: 0.0009562  loss_rpn_loc: 0.005362     lr: 0.00015984  max_mem: 6054M
# [06/04 20:06:44 d2.utils.events]:  eta: 1:01:37  iter: 659  total_loss: 0.2657  loss_cls: 0.05146  loss_box_reg: 0.09457  loss_mask: 0.1132  loss_rpn_cls: 0.0004538  loss_rpn_loc: 0.006129     lr: 0.00016484  max_mem: 6054M
# Loss has not improved for 100 iterations
# [06/04 20:06:52 d2.utils.events]:  eta: 1:00:18  iter: 679  total_loss: 0.2454  loss_cls: 0.05333  loss_box_reg: 0.08146  loss_mask: 0.09575  loss_rpn_cls: 9.483e-05  loss_rpn_loc: 0.006687     lr: 0.00016983  max_mem: 6054M
# [06/04 20:07:00 d2.utils.events]:  eta: 0:58:10  iter: 699  total_loss: 0.3535  loss_cls: 0.06657  loss_box_reg: 0.09253  loss_mask: 0.1552  loss_rpn_cls: 0.0003644  loss_rpn_loc: 0.00718     lr: 0.00017483  max_mem: 6054M
# [06/04 20:07:08 d2.utils.events]:  eta: 1:02:12  iter: 719  total_loss: 0.2527  loss_cls: 0.04995  loss_box_reg: 0.06713  loss_mask: 0.1147  loss_rpn_cls: 0.0007087  loss_rpn_loc: 0.005982     lr: 0.00017982  max_mem: 6054M
# [06/04 20:07:15 d2.utils.events]:  eta: 0:58:31  iter: 739  total_loss: 0.2139  loss_cls: 0.03661  loss_box_reg: 0.05547  loss_mask: 0.1099  loss_rpn_cls: 0.0001268  loss_rpn_loc: 0.005947     lr: 0.00018482  max_mem: 6054M
# [06/04 20:07:23 d2.utils.events]:  eta: 1:00:46  iter: 759  total_loss: 0.3134  loss_cls: 0.06617  loss_box_reg: 0.09408  loss_mask: 0.1331  loss_rpn_cls: 0.001049  loss_rpn_loc: 0.007096     lr: 0.00018981  max_mem: 6054M
# [06/04 20:07:31 d2.utils.events]:  eta: 0:59:46  iter: 779  total_loss: 0.2074  loss_cls: 0.03993  loss_box_reg: 0.05864  loss_mask: 0.08956  loss_rpn_cls: 0.0004064  loss_rpn_loc: 0.007131     lr: 0.00019481  max_mem: 6054M
# [06/04 20:07:39 d2.utils.events]:  eta: 0:59:21  iter: 799  total_loss: 0.2685  loss_cls: 0.05261  loss_box_reg: 0.08408  loss_mask: 0.08562  loss_rpn_cls: 0.0001853  loss_rpn_loc: 0.00587     lr: 0.0001998  max_mem: 6054M
# [06/04 20:07:46 d2.utils.events]:  eta: 0:58:41  iter: 819  total_loss: 0.3115  loss_cls: 0.05982  loss_box_reg: 0.07142  loss_mask: 0.1488  loss_rpn_cls: 0.0003603  loss_rpn_loc: 0.007286     lr: 0.0002048  max_mem: 6054M
# [06/04 20:07:54 d2.utils.events]:  eta: 0:58:52  iter: 839  total_loss: 0.2125  loss_cls: 0.038  loss_box_reg: 0.05796  loss_mask: 0.1027  loss_rpn_cls: 0.0003601  loss_rpn_loc: 0.00497     lr: 0.00020979  max_mem: 6054M
# [06/04 20:08:02 d2.utils.events]:  eta: 0:59:43  iter: 859  total_loss: 0.1688  loss_cls: 0.03473  loss_box_reg: 0.04283  loss_mask: 0.08614  loss_rpn_cls: 7.841e-05  loss_rpn_loc: 0.00653     lr: 0.00021479  max_mem: 6054M
# [06/04 20:08:10 d2.utils.events]:  eta: 0:59:47  iter: 879  total_loss: 0.2226  loss_cls: 0.0423  loss_box_reg: 0.06344  loss_mask: 0.1032  loss_rpn_cls: 0.0002575  loss_rpn_loc: 0.005275     lr: 0.00021978  max_mem: 6054M
# Loss has not improved for 100 iterations
# [06/04 20:08:18 d2.utils.events]:  eta: 1:00:16  iter: 899  total_loss: 0.2375  loss_cls: 0.04757  loss_box_reg: 0.06552  loss_mask: 0.1119  loss_rpn_cls: 0.0002394  loss_rpn_loc: 0.003838     lr: 0.00022478  max_mem: 6054M
# [06/04 20:08:26 d2.utils.events]:  eta: 0:58:46  iter: 919  total_loss: 0.2342  loss_cls: 0.04677  loss_box_reg: 0.05096  loss_mask: 0.1098  loss_rpn_cls: 0.0004634  loss_rpn_loc: 0.005831     lr: 0.00022977  max_mem: 6054M
# [06/04 20:08:33 d2.utils.events]:  eta: 0:57:53  iter: 939  total_loss: 0.2085  loss_cls: 0.04144  loss_box_reg: 0.0628  loss_mask: 0.1212  loss_rpn_cls: 0.0002711  loss_rpn_loc: 0.006657     lr: 0.00023477  max_mem: 6054M
# [06/04 20:08:41 d2.utils.events]:  eta: 0:56:47  iter: 959  total_loss: 0.2063  loss_cls: 0.03989  loss_box_reg: 0.05728  loss_mask: 0.09886  loss_rpn_cls: 0.0003381  loss_rpn_loc: 0.006114     lr: 0.00023976  max_mem: 6054M
# [06/04 20:08:49 d2.utils.events]:  eta: 0:58:22  iter: 979  total_loss: 0.1943  loss_cls: 0.03712  loss_box_reg: 0.05033  loss_mask: 0.1057  loss_rpn_cls: 7.338e-05  loss_rpn_loc: 0.004824     lr: 0.00024476  max_mem: 6054M
# [06/04 20:08:56 d2.utils.events]:  eta: 0:56:23  iter: 999  total_loss: 0.1808  loss_cls: 0.02884  loss_box_reg: 0.04608  loss_mask: 0.08354  loss_rpn_cls: 0.0003346  loss_rpn_loc: 0.005973     lr: 0.00024975  max_mem: 6054M
# [06/04 20:09:04 d2.utils.events]:  eta: 0:56:38  iter: 1019  total_loss: 0.2384  loss_cls: 0.04514  loss_box_reg: 0.06064  loss_mask: 0.107  loss_rpn_cls: 0.0001665  loss_rpn_loc: 0.00665     lr: 0.00025  max_mem: 6054M
# [06/04 20:09:11 d2.utils.events]:  eta: 0:55:49  iter: 1039  total_loss: 0.1917  loss_cls: 0.03027  loss_box_reg: 0.04629  loss_mask: 0.103  loss_rpn_cls: 0.0001549  loss_rpn_loc: 0.006244     lr: 0.00025  max_mem: 6054M
# [06/04 20:09:19 d2.utils.events]:  eta: 0:55:03  iter: 1059  total_loss: 0.1909  loss_cls: 0.03499  loss_box_reg: 0.04083  loss_mask: 0.09084  loss_rpn_cls: 6.733e-05  loss_rpn_loc: 0.004083     lr: 0.00025  max_mem: 6054M
# [06/04 20:09:26 d2.utils.events]:  eta: 0:57:39  iter: 1079  total_loss: 0.1893  loss_cls: 0.03812  loss_box_reg: 0.05312  loss_mask: 0.1008  loss_rpn_cls: 0.0004975  loss_rpn_loc: 0.005269     lr: 0.00025  max_mem: 6054M
# [06/04 20:09:34 d2.utils.events]:  eta: 0:56:20  iter: 1099  total_loss: 0.1828  loss_cls: 0.03333  loss_box_reg: 0.04121  loss_mask: 0.09705  loss_rpn_cls: 0.0003241  loss_rpn_loc: 0.005188     lr: 0.00025  max_mem: 6054M
# [06/04 20:09:42 d2.utils.events]:  eta: 0:58:15  iter: 1119  total_loss: 0.1788  loss_cls: 0.03213  loss_box_reg: 0.04176  loss_mask: 0.09201  loss_rpn_cls: 0.0002326  loss_rpn_loc: 0.005732     lr: 0.00025  max_mem: 6054M
# Loss has not improved for 100 iterations
# [06/04 20:09:49 d2.utils.events]:  eta: 0:54:46  iter: 1139  total_loss: 0.2043  loss_cls: 0.03361  loss_box_reg: 0.05023  loss_mask: 0.1069  loss_rpn_cls: 3.566e-05  loss_rpn_loc: 0.004132     lr: 0.00025  max_mem: 6054M
# [06/04 20:09:57 d2.utils.events]:  eta: 0:56:47  iter: 1159  total_loss: 0.1825  loss_cls: 0.02861  loss_box_reg: 0.04038  loss_mask: 0.0926  loss_rpn_cls: 5.696e-05  loss_rpn_loc: 0.00503     lr: 0.00025  max_mem: 6054M
# [06/04 20:10:05 d2.utils.events]:  eta: 0:56:01  iter: 1179  total_loss: 0.203  loss_cls: 0.03418  loss_box_reg: 0.0394  loss_mask: 0.1163  loss_rpn_cls: 0.0001895  loss_rpn_loc: 0.004724     lr: 0.00025  max_mem: 6054M
# [06/04 20:10:12 d2.utils.events]:  eta: 0:55:41  iter: 1199  total_loss: 0.183  loss_cls: 0.03097  loss_box_reg: 0.04193  loss_mask: 0.09107  loss_rpn_cls: 4.446e-05  loss_rpn_loc: 0.004504     lr: 0.00025  max_mem: 6054M
# [06/04 20:10:20 d2.utils.events]:  eta: 0:55:52  iter: 1219  total_loss: 0.163  loss_cls: 0.02982  loss_box_reg: 0.0381  loss_mask: 0.08263  loss_rpn_cls: 7.41e-05  loss_rpn_loc: 0.004675     lr: 0.00025  max_mem: 6054M
# [06/04 20:10:27 d2.utils.events]:  eta: 0:53:07  iter: 1239  total_loss: 0.16  loss_cls: 0.02769  loss_box_reg: 0.03717  loss_mask: 0.09375  loss_rpn_cls: 0.0002612  loss_rpn_loc: 0.00424     lr: 0.00025  max_mem: 6054M
# [06/04 20:10:35 d2.utils.events]:  eta: 0:57:50  iter: 1259  total_loss: 0.1991  loss_cls: 0.03435  loss_box_reg: 0.04884  loss_mask: 0.1041  loss_rpn_cls: 0.0006913  loss_rpn_loc: 0.004705     lr: 0.00025  max_mem: 6054M
# [06/04 20:10:42 d2.utils.events]:  eta: 0:53:44  iter: 1279  total_loss: 0.1335  loss_cls: 0.01939  loss_box_reg: 0.03181  loss_mask: 0.07079  loss_rpn_cls: 7.666e-05  loss_rpn_loc: 0.004791     lr: 0.00025  max_mem: 6054M
# [06/04 20:10:50 d2.utils.events]:  eta: 0:55:10  iter: 1299  total_loss: 0.1634  loss_cls: 0.02473  loss_box_reg: 0.03314  loss_mask: 0.103  loss_rpn_cls: 0.000156  loss_rpn_loc: 0.003712     lr: 0.00025  max_mem: 6054M
# [06/04 20:10:58 d2.utils.events]:  eta: 0:54:45  iter: 1319  total_loss: 0.1779  loss_cls: 0.02922  loss_box_reg: 0.03453  loss_mask: 0.1039  loss_rpn_cls: 0.000106  loss_rpn_loc: 0.005219     lr: 0.00025  max_mem: 6054M
# Loss has not improved for 100 iterations
# [06/04 20:11:06 d2.utils.events]:  eta: 0:57:38  iter: 1339  total_loss: 0.1706  loss_cls: 0.02922  loss_box_reg: 0.03961  loss_mask: 0.08282  loss_rpn_cls: 5.278e-05  loss_rpn_loc: 0.005405     lr: 0.00025  max_mem: 6054M
# [06/04 20:11:13 d2.utils.events]:  eta: 0:53:01  iter: 1359  total_loss: 0.1585  loss_cls: 0.02541  loss_box_reg: 0.03216  loss_mask: 0.09766  loss_rpn_cls: 7.659e-05  loss_rpn_loc: 0.004263     lr: 0.00025  max_mem: 6054M
# [06/04 20:11:20 d2.utils.events]:  eta: 0:52:32  iter: 1379  total_loss: 0.1351  loss_cls: 0.01904  loss_box_reg: 0.02602  loss_mask: 0.08657  loss_rpn_cls: 4.62e-05  loss_rpn_loc: 0.005254     lr: 0.00025  max_mem: 6054M
# [06/04 20:11:28 d2.utils.events]:  eta: 0:52:45  iter: 1399  total_loss: 0.1551  loss_cls: 0.02403  loss_box_reg: 0.03416  loss_mask: 0.08436  loss_rpn_cls: 4.057e-05  loss_rpn_loc: 0.004349     lr: 0.00025  max_mem: 6054M
# [06/04 20:11:35 d2.utils.events]:  eta: 0:55:33  iter: 1419  total_loss: 0.1772  loss_cls: 0.03165  loss_box_reg: 0.04266  loss_mask: 0.08961  loss_rpn_cls: 0.0001287  loss_rpn_loc: 0.005641     lr: 0.00025  max_mem: 6054M
# [06/04 20:11:43 d2.utils.events]:  eta: 0:54:26  iter: 1439  total_loss: 0.18  loss_cls: 0.02816  loss_box_reg: 0.04348  loss_mask: 0.1025  loss_rpn_cls: 9.353e-05  loss_rpn_loc: 0.005078     lr: 0.00025  max_mem: 6054M
# [06/04 20:11:50 d2.utils.events]:  eta: 0:52:14  iter: 1459  total_loss: 0.1472  loss_cls: 0.02097  loss_box_reg: 0.03194  loss_mask: 0.08389  loss_rpn_cls: 4.503e-05  loss_rpn_loc: 0.004421     lr: 0.00025  max_mem: 6054M
# [06/04 20:11:58 d2.utils.events]:  eta: 0:53:56  iter: 1479  total_loss: 0.1555  loss_cls: 0.02582  loss_box_reg: 0.03666  loss_mask: 0.09046  loss_rpn_cls: 5.963e-05  loss_rpn_loc: 0.004717     lr: 0.00025  max_mem: 6054M
# Loss has not improved for 100 iterations
# [06/04 20:12:05 d2.utils.events]:  eta: 0:52:29  iter: 1499  total_loss: 0.1757  loss_cls: 0.02283  loss_box_reg: 0.0356  loss_mask: 0.0955  loss_rpn_cls: 8.114e-05  loss_rpn_loc: 0.004732     lr: 0.00025  max_mem: 6054M
# [06/04 20:12:13 d2.utils.events]:  eta: 0:54:17  iter: 1519  total_loss: 0.1501  loss_cls: 0.02308  loss_box_reg: 0.02872  loss_mask: 0.08899  loss_rpn_cls: 0.000283  loss_rpn_loc: 0.003429     lr: 0.00025  max_mem: 6054M
# [06/04 20:12:20 d2.utils.events]:  eta: 0:51:57  iter: 1539  total_loss: 0.1795  loss_cls: 0.03207  loss_box_reg: 0.04486  loss_mask: 0.09217  loss_rpn_cls: 0.0002744  loss_rpn_loc: 0.004687     lr: 0.00025  max_mem: 6054M
# [06/04 20:12:28 d2.utils.events]:  eta: 0:53:44  iter: 1559  total_loss: 0.1715  loss_cls: 0.02853  loss_box_reg: 0.04362  loss_mask: 0.09319  loss_rpn_cls: 0.0001191  loss_rpn_loc: 0.003609     lr: 0.00025  max_mem: 6054M
# [06/04 20:12:35 d2.utils.events]:  eta: 0:52:13  iter: 1579  total_loss: 0.1314  loss_cls: 0.02303  loss_box_reg: 0.03197  loss_mask: 0.08571  loss_rpn_cls: 0.0001198  loss_rpn_loc: 0.004954     lr: 0.00025  max_mem: 6054M
# Loss has not improved for 200 iterations
# [06/04 20:12:43 d2.utils.events]:  eta: 0:52:02  iter: 1599  total_loss: 0.1782  loss_cls: 0.02271  loss_box_reg: 0.03073  loss_mask: 0.09395  loss_rpn_cls: 4.038e-05  loss_rpn_loc: 0.006249     lr: 0.00025  max_mem: 6054M
# [06/04 20:12:50 d2.utils.events]:  eta: 0:51:29  iter: 1619  total_loss: 0.1507  loss_cls: 0.02458  loss_box_reg: 0.02743  loss_mask: 0.08928  loss_rpn_cls: 4.348e-05  loss_rpn_loc: 0.00432     lr: 0.00025  max_mem: 6054M
# [06/04 20:12:58 d2.utils.events]:  eta: 0:53:09  iter: 1639  total_loss: 0.16  loss_cls: 0.02553  loss_box_reg: 0.03337  loss_mask: 0.08644  loss_rpn_cls: 0.0001538  loss_rpn_loc: 0.005028     lr: 0.00025  max_mem: 6054M
# [06/04 20:13:06 d2.utils.events]:  eta: 0:53:24  iter: 1659  total_loss: 0.1436  loss_cls: 0.02045  loss_box_reg: 0.02875  loss_mask: 0.07594  loss_rpn_cls: 0.0001892  loss_rpn_loc: 0.00501     lr: 0.00025  max_mem: 6054M
# [06/04 20:13:13 d2.utils.events]:  eta: 0:52:09  iter: 1679  total_loss: 0.1717  loss_cls: 0.02182  loss_box_reg: 0.03873  loss_mask: 0.08842  loss_rpn_cls: 6.349e-05  loss_rpn_loc: 0.004679     lr: 0.00025  max_mem: 6054M
# Loss has not improved for 300 iterations
# [06/04 20:13:21 d2.utils.events]:  eta: 0:51:50  iter: 1699  total_loss: 0.1347  loss_cls: 0.02056  loss_box_reg: 0.02921  loss_mask: 0.08368  loss_rpn_cls: 1.83e-05  loss_rpn_loc: 0.004764     lr: 0.00025  max_mem: 6054M
# [06/04 20:13:28 d2.utils.events]:  eta: 0:52:06  iter: 1719  total_loss: 0.1564  loss_cls: 0.02814  loss_box_reg: 0.04071  loss_mask: 0.08564  loss_rpn_cls: 2.104e-05  loss_rpn_loc: 0.003852     lr: 0.00025  max_mem: 6054M
# [06/04 20:13:36 d2.utils.events]:  eta: 0:53:39  iter: 1739  total_loss: 0.1754  loss_cls: 0.02705  loss_box_reg: 0.044  loss_mask: 0.09995  loss_rpn_cls: 6.382e-05  loss_rpn_loc: 0.004078     lr: 0.00025  max_mem: 6054M
# [06/04 20:13:43 d2.utils.events]:  eta: 0:49:46  iter: 1759  total_loss: 0.1291  loss_cls: 0.02033  loss_box_reg: 0.02349  loss_mask: 0.07818  loss_rpn_cls: 6.705e-05  loss_rpn_loc: 0.003574     lr: 0.00025  max_mem: 6054M
# [06/04 20:13:51 d2.utils.events]:  eta: 0:52:39  iter: 1779  total_loss: 0.119  loss_cls: 0.01674  loss_box_reg: 0.02685  loss_mask: 0.07181  loss_rpn_cls: 2.071e-05  loss_rpn_loc: 0.004278     lr: 0.00025  max_mem: 6054M
# Loss has not improved for 400 iterations
# [06/04 20:13:58 d2.utils.events]:  eta: 0:49:52  iter: 1799  total_loss: 0.1464  loss_cls: 0.01995  loss_box_reg: 0.0293  loss_mask: 0.08764  loss_rpn_cls: 0.0001573  loss_rpn_loc: 0.004678     lr: 0.00025  max_mem: 6054M
# [06/04 20:14:06 d2.utils.events]:  eta: 0:51:27  iter: 1819  total_loss: 0.1476  loss_cls: 0.02548  loss_box_reg: 0.03426  loss_mask: 0.07649  loss_rpn_cls: 4.605e-05  loss_rpn_loc: 0.004133     lr: 0.00025  max_mem: 6054M
# [06/04 20:14:13 d2.utils.events]:  eta: 0:51:48  iter: 1839  total_loss: 0.185  loss_cls: 0.02676  loss_box_reg: 0.04613  loss_mask: 0.09158  loss_rpn_cls: 4.663e-05  loss_rpn_loc: 0.006672     lr: 0.00025  max_mem: 6054M
# [06/04 20:14:21 d2.utils.events]:  eta: 0:52:35  iter: 1859  total_loss: 0.1373  loss_cls: 0.02268  loss_box_reg: 0.02924  loss_mask: 0.07725  loss_rpn_cls: 6.212e-05  loss_rpn_loc: 0.004282     lr: 0.00025  max_mem: 6054M
# [06/04 20:14:29 d2.utils.events]:  eta: 0:51:16  iter: 1879  total_loss: 0.1292  loss_cls: 0.0195  loss_box_reg: 0.0279  loss_mask: 0.07348  loss_rpn_cls: 5.738e-05  loss_rpn_loc: 0.004101     lr: 0.00025  max_mem: 6054M
# Loss has not improved for 500 iterations
# EARLY STOPPING
# WARNING [06/04 20:14:32 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [06/04 20:14:32 d2.data.datasets.coco]: Loaded 40 images in COCO format from ./data-cat-2/valid/_annotations.coco.json
# [06/04 20:14:32 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [06/04 20:14:32 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [06/04 20:14:32 d2.data.common]: Serializing 40 elements to byte tensors and concatenating them all ...
# [06/04 20:14:32 d2.data.common]: Serialized dataset takes 0.11 MiB
# [06/04 20:14:32 d2.evaluation.evaluator]: Start inference on 40 batches
# [06/04 20:14:33 d2.evaluation.evaluator]: Inference done 11/40. Dataloading: 0.0066 s/iter. Inference: 0.0920 s/iter. Eval: 0.0117 s/iter. Total: 0.1103 s/iter. ETA=0:00:03
# [06/04 20:14:36 d2.evaluation.evaluator]: Total inference time: 0:00:03.362971 (0.096085 s / iter per device, on 1 devices)
# [06/04 20:14:36 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:03 (0.085761 s / iter per device, on 1 devices)
# [06/04 20:14:36 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [06/04 20:14:36 d2.evaluation.coco_evaluation]: Saving results to ./output/inference/cats-valid/coco_instances_results.json
# [06/04 20:14:36 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [06/04 20:14:36 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [06/04 20:14:36 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.01 seconds.
# [06/04 20:14:36 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [06/04 20:14:36 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.759
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.933
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.913
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.053
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.789
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.696
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.790
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.797
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.233
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.823
# [06/04 20:14:36 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm  |  APl   |
# |:------:|:------:|:------:|:-----:|:-----:|:------:|
# | 75.885 | 93.348 | 91.321 |  nan  | 5.297 | 78.879 |
# [06/04 20:14:36 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [06/04 20:14:36 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP   | category   | AP     | category   | AP     |
# |:-----------|:-----|:-----------|:-------|:-----------|:-------|
# | data-cat   | nan  | 0          | 75.238 | 1          | 76.531 |
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [06/04 20:14:36 d2.evaluation.fast_eval_api]: Evaluate annotation type *segm*
# [06/04 20:14:36 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.02 seconds.
# [06/04 20:14:36 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [06/04 20:14:36 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.766
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.933
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.894
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.048
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.796
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.787
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.793
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.200
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.820
# [06/04 20:14:36 d2.evaluation.coco_evaluation]: Evaluation results for segm:
# |   AP   |  AP50  |  AP75  |  APs  |  APm  |  APl   |
# |:------:|:------:|:------:|:-----:|:-----:|:------:|
# | 76.585 | 93.348 | 89.384 |  nan  | 4.781 | 79.572 |
# [06/04 20:14:36 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [06/04 20:14:36 d2.evaluation.coco_evaluation]: Per-category segm AP:
# | category   | AP   | category   | AP     | category   | AP     |
# |:-----------|:-----|:-----------|:-------|:-----------|:-------|
# | data-cat   | nan  | 0          | 76.363 | 1          | 76.807 |
# [06/04 20:14:36 detectron2]: Evaluation results for cats-valid in csv format:
# [06/04 20:14:36 d2.evaluation.testing]: copypaste: Task: bbox
# [06/04 20:14:36 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [06/04 20:14:36 d2.evaluation.testing]: copypaste: 75.8847,93.3484,91.3211,nan,5.2970,78.8795
# [06/04 20:14:36 d2.evaluation.testing]: copypaste: Task: segm
# [06/04 20:14:36 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [06/04 20:14:36 d2.evaluation.testing]: copypaste: 76.5849,93.3484,89.3839,nan,4.7808,79.5719
# OrderedDict([('bbox',
#               {'AP': 75.88469192210391,
#                'AP50': 93.34843422230423,
#                'AP75': 91.32108863060219,
#                'APs': nan,
#                'APm': 5.297029702970296,
#                'APl': 78.87946954166902,
#                'AP-data-cat': nan,
#                'AP-0': 75.23790733110577,
#                'AP-1': 76.53147651310204}),
#              ('segm',
#               {'AP': 76.58493895288314,
#                'AP50': 93.34843422230423,
#                'AP75': 89.38393839383939,
#                'APs': nan,
#                'APm': 4.78076379066478,
#                'APl': 79.57194435834191,
#                'AP-data-cat': nan,
#                'AP-0': 76.36322762711055,
#                'AP-1': 76.80665027865572})])

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from detectron2.utils.visualizer import ColorMode
dataset_dicts = DatasetCatalog.get("cats-valid")
for d in random.sample(dataset_dicts, 4):    
    im = cv2.imread(d["file_name"])
    outputs = predictor(im) 
    v = Visualizer(im[:, :, ::-1],
                    
                   scale=0.5, 
                   instance_mode=ColorMode.IMAGE_BW  
    )
    out = v.draw_instance_predictions(outputs["instances"].to("cpu"))
    plt.figure(figsize=(15,7))
    plt.imshow(out.get_image()[:, :, ::-1])
# Out:
# WARNING [06/04 20:15:20 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [06/04 20:15:20 d2.data.datasets.coco]: Loaded 40 images in COCO format from ./data-cat-2/valid/_annotations.coco.json

# %%
from google.colab import files
files.download(os.path.join(cfg.OUTPUT_DIR, "model_final.pth"))
